# %% [markdown]
# <a href="https://colab.research.google.com/github/hoangthanh300405-ops/football-ai-colab-/blob/main/ranking_players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lineups.csv')
df.head(15)
# Out:
#     eventId             teamId homeAway  starter  athleteDisplayName    Pos  \
# 0    704279  Manchester United     home        1         André Onana     GK
# 1    704279  Manchester United     home        1   Noussair Mazraoui     DF
# 2    704279  Manchester United     home        1         Diogo Dalot     DF
# 3    704279  Manchester United     home        1       Kobbie Mainoo     MF
# 4    704279  Manchester United     home        1       Harry Maguire     DF
# 5    704279  Manchester United     home        1   Lisandro Martínez     DF
# 6    704279  Manchester United     home        1                Amad    NaN
# 7    704279  Manchester United     home        1            Casemiro     MF
# 8    704279  Manchester United     home        1     Bruno Fernandes     MF
# 9    704279  Manchester United     home        1         Mason Mount     MF
# 10   704279  Manchester United     home        1     Marcus Rashford     FW
# 11   704279  Manchester United     home        1     Marcus Rashford  FW,MF
# 12   704279  Manchester United     home        0      Altay Bayindir    NaN
# 13   704279  Manchester United     home        0         Jonny Evans     DF
# 14   704279  Manchester United     home        0  Alejandro Garnacho  MF,FW
#
#      Age  Min/Match  Save%  GA/Match  ...        DEF    Save_n   CS_n  \
# 0   28.0      90.00   68.9      1.29  ...   0.000000  0.481667  0.265
# 1   26.0      76.70    NaN       NaN  ...  41.314408  0.000000  0.000
# 2   25.0      85.27    NaN       NaN  ...  41.643593  0.000000  0.000
# 3   19.0      66.04    NaN       NaN  ...   0.000000  0.000000  0.000
# 4   31.0      65.11    NaN       NaN  ...  43.860164  0.000000  0.000
# 5   26.0      87.55    NaN       NaN  ...  51.113031  0.000000  0.000
# 6    NaN        NaN    NaN       NaN  ...   0.000000  0.000000  0.000
# 7   32.0      62.25    NaN       NaN  ...   0.000000  0.000000  0.000
# 8   29.0      83.83    NaN       NaN  ...   0.000000  0.000000  0.000
# 9   25.0      36.59    NaN       NaN  ...   0.000000  0.000000  0.000
# 10  26.0      44.40    NaN       NaN  ...   0.000000  0.000000  0.000
# 11  26.0      65.20    NaN       NaN  ...   0.000000  0.000000  0.000
# 12   NaN        NaN    NaN       NaN  ...   0.000000  0.000000  0.000
# 13  36.0      45.00    NaN       NaN  ...  39.875460  0.000000  0.000
# 14  20.0      61.08    NaN       NaN  ...   0.000000  0.000000  0.000
#
#     GA_gk_n  PK_n         GK     Rating   ATK_team   DEF_team    GK_team
# 0      0.43  0.25  19.883333  19.883333  21.216109  19.559019  19.883333
# 1      0.00  0.00   0.000000  41.314408  21.216109  19.559019  19.883333
# 2      0.00  0.00   0.000000  41.643593  21.216109  19.559019  19.883333
# 3      0.00  0.00   0.000000   4.450421  21.216109  19.559019  19.883333
# 4      0.00  0.00   0.000000  43.860164  21.216109  19.559019  19.883333
# 5      0.00  0.00   0.000000  51.113031  21.216109  19.559019  19.883333
# 6      0.00  0.00   0.000000   0.000000  21.216109  19.559019  19.883333
# 7      0.00  0.00   0.000000   6.001932  21.216109  19.559019  19.883333
# 8      0.00  0.00   0.000000  43.802964  21.216109  19.559019  19.883333
# 9      0.00  0.00   0.000000   5.036202  21.216109  19.559019  19.883333
# 10     0.00  0.00   0.000000   0.000000  21.216109  19.559019  19.883333
# 11     0.00  0.00   0.000000  24.010555  21.216109  19.559019  19.883333
# 12     0.00  0.00   0.000000   0.000000  21.216109  19.559019  19.883333
# 13     0.00  0.00   0.000000  39.875460  21.216109  19.559019  19.883333
# 14     0.00  0.00   0.000000  34.221523  21.216109  19.559019  19.883333
#
# [15 rows x 46 columns]

# %%
import pandas as pd


def normalize(col):
    valid = col.dropna()
    if valid.empty or valid.max() == valid.min():
        return pd.Series(0.0, index=col.index)
    return ((col - valid.min()) / (valid.max() - valid.min())).fillna(0)

df['Pos'] = df['Pos'].fillna('').astype(str)

# PERSONAL POINT

df['GA_n']    = normalize(df['G+A/Match'])
df['xAG_n']   = normalize(df['xAG'])
df['PrgC_n']  = normalize(df['PrgC'])

df['ATK'] = 100 * (
    0.50 * df['GA_n'] +
    0.30 * df['xAG_n'] +
    0.20 * df['PrgC_n']
)


df['Clr_n'] = normalize(df['Clr/Match'])
df['Tkl_n'] = normalize(df['TklW%'])
df['Blk_n'] = normalize(df['Blocks/Match'])
df['Int_n'] = normalize(df['Int/Match'])
df['Err_n'] = normalize(df['Err/Match'])

df['DEF'] = 100 * (
    0.30 * df['Tkl_n'] +
    0.25 * df['Int_n'] +
    0.20 * df['Clr_n'] +
    0.15 * df['Blk_n'] -
    0.10 * df['Err_n']
)


df['Save_n']  = normalize(df['Save%'])
df['CS_n']    = normalize(df['CS%'])
df['GA_gk_n'] = normalize(df['GA/Match'])
df['PK_n']    = normalize(df['PKsv%'])

df['GK'] = 100 * (
    0.35 * df['Save_n'] +
    0.25 * df['CS_n'] +
    0.20 * df['PK_n'] -
    0.20 * df['GA_gk_n']
)


# RATING
def calc_rating(row):
    pos = row['Pos']
    if pos == '':
        return 0
    if 'GK' in pos:
        return row['GK']
    if 'DF' in pos and 'MF' in pos:
        return 0.65 * row['DEF'] + 0.35 * row['ATK']
    if 'MF' in pos and 'FW' in pos:
        return 0.70 * row['ATK'] + 0.30 * row['DEF']
    if 'DF' in pos:
        return row['DEF']
    if 'MF' in pos:
        return 0.60 * row['ATK'] + 0.40 * row['DEF']
    if 'FW' in pos:
        return row['ATK']
    return 0

df['Rating'] = df.apply(calc_rating, axis=1)

df.loc[df['Min/Match'] < 30, ['ATK','DEF','GK','Rating']] *= 0.5

# TEAM

atk_team = (
    df[df['Pos'].str.contains('FW|MF')]
    .groupby('teamId')['ATK']
    .mean()
    .rename('ATK_team')
)

def_team = (
    df[df['Pos'].str.contains('DF|MF')]
    .groupby('teamId')['DEF']
    .mean()
    .rename('DEF_team')
)

gk_team = (
    df[df['Pos'].str.contains('GK')]
    .groupby('teamId')['GK']
    .mean()
    .rename('GK_team')
)

df = df.merge(atk_team, on='teamId', how='left')
df = df.merge(def_team, on='teamId', how='left')
df = df.merge(gk_team, on='teamId', how='left')


norm_cols = [c for c in df.columns if c.endswith('_n')]
df.drop(columns=norm_cols, inplace=True)


df.head(20)
# Out:
#     eventId             teamId homeAway  starter  athleteDisplayName    Pos  \
# 0    704279  Manchester United     home        1         André Onana     GK
# 1    704279  Manchester United     home        1   Noussair Mazraoui     DF
# 2    704279  Manchester United     home        1         Diogo Dalot     DF
# 3    704279  Manchester United     home        1       Kobbie Mainoo     MF
# 4    704279  Manchester United     home        1       Harry Maguire     DF
# 5    704279  Manchester United     home        1   Lisandro Martínez     DF
# 6    704279  Manchester United     home        1                Amad
# 7    704279  Manchester United     home        1            Casemiro     MF
# 8    704279  Manchester United     home        1     Bruno Fernandes     MF
# 9    704279  Manchester United     home        1         Mason Mount     MF
# 10   704279  Manchester United     home        1     Marcus Rashford     FW
# 11   704279  Manchester United     home        1     Marcus Rashford  FW,MF
# 12   704279  Manchester United     home        0      Altay Bayindir
# 13   704279  Manchester United     home        0         Jonny Evans     DF
# 14   704279  Manchester United     home        0  Alejandro Garnacho  MF,FW
# 15   704279  Manchester United     home        0        Toby Collyer     MF
# 16   704279  Manchester United     home        0              Antony  DF,MF
# 17   704279  Manchester United     home        0      Joshua Zirkzee  FW,MF
# 18   704279  Manchester United     home        0     Scott McTominay     MF
# 19   704279  Manchester United     home        0    Matthijs de Ligt     DF
#
#      Age  Min/Match  Save%  GA/Match  ...        ATK        DEF         GK  \
# 0   28.0      90.00   68.9      1.29  ...   0.000000   0.000000  19.883333
# 1   26.0      76.70    NaN       NaN  ...   0.000000  41.314408   0.000000
# 2   25.0      85.27    NaN       NaN  ...   0.000000  41.643593   0.000000
# 3   19.0      66.04    NaN       NaN  ...   7.417368   0.000000   0.000000
# 4   31.0      65.11    NaN       NaN  ...   0.000000  43.860164   0.000000
# 5   26.0      87.55    NaN       NaN  ...   0.000000  51.113031   0.000000
# 6    NaN        NaN    NaN       NaN  ...   0.000000   0.000000   0.000000
# 7   32.0      62.25    NaN       NaN  ...  10.003220   0.000000   0.000000
# 8   29.0      83.83    NaN       NaN  ...  73.004941   0.000000   0.000000
# 9   25.0      36.59    NaN       NaN  ...   8.393671   0.000000   0.000000
# 10  26.0      44.40    NaN       NaN  ...   0.000000   0.000000   0.000000
# 11  26.0      65.20    NaN       NaN  ...  34.300793   0.000000   0.000000
# 12   NaN        NaN    NaN       NaN  ...   0.000000   0.000000   0.000000
# 13  36.0      45.00    NaN       NaN  ...   0.000000  39.875460   0.000000
# 14  20.0      61.08    NaN       NaN  ...  48.887890   0.000000   0.000000
# 15  20.0      29.83    NaN       NaN  ...   0.412844   0.000000   0.000000
# 16  24.0      17.62    NaN       NaN  ...   0.480080   9.783654   0.000000
# 17  23.0      43.81    NaN       NaN  ...  15.421249   0.000000   0.000000
# 18  27.0       9.50    NaN       NaN  ...   0.000000   0.000000   0.000000
# 19  24.0      73.21    NaN       NaN  ...   0.000000  51.329061   0.000000
#
#        Rating  ATK_team_x  DEF_team_x  GK_team_x  ATK_team_y  DEF_team_y  \
# 0   19.883333   21.216109   19.559019  19.883333   21.216109   19.559019
# 1   41.314408   21.216109   19.559019  19.883333   21.216109   19.559019
# 2   41.643593   21.216109   19.559019  19.883333   21.216109   19.559019
# 3    4.450421   21.216109   19.559019  19.883333   21.216109   19.559019
# 4   43.860164   21.216109   19.559019  19.883333   21.216109   19.559019
# 5   51.113031   21.216109   19.559019  19.883333   21.216109   19.559019
# 6    0.000000   21.216109   19.559019  19.883333   21.216109   19.559019
# 7    6.001932   21.216109   19.559019  19.883333   21.216109   19.559019
# 8   43.802964   21.216109   19.559019  19.883333   21.216109   19.559019
# 9    5.036202   21.216109   19.559019  19.883333   21.216109   19.559019
# 10   0.000000   21.216109   19.559019  19.883333   21.216109   19.559019
# 11  24.010555   21.216109   19.559019  19.883333   21.216109   19.559019
# 12   0.000000   21.216109   19.559019  19.883333   21.216109   19.559019
# 13  39.875460   21.216109   19.559019  19.883333   21.216109   19.559019
# 14  34.221523   21.216109   19.559019  19.883333   21.216109   19.559019
# 15   0.247706   21.216109   19.559019  19.883333   21.216109   19.559019
# 16   6.527403   21.216109   19.559019  19.883333   21.216109   19.559019
# 17  10.794874   21.216109   19.559019  19.883333   21.216109   19.559019
# 18   0.000000   21.216109   19.559019  19.883333   21.216109   19.559019
# 19  51.329061   21.216109   19.559019  19.883333   21.216109   19.559019
#
#     GK_team_y
# 0   19.883333
# 1   19.883333
# 2   19.883333
# 3   19.883333
# 4   19.883333
# 5   19.883333
# 6   19.883333
# 7   19.883333
# 8   19.883333
# 9   19.883333
# 10  19.883333
# 11  19.883333
# 12  19.883333
# 13  19.883333
# 14  19.883333
# 15  19.883333
# 16  19.883333
# 17  19.883333
# 18  19.883333
# 19  19.883333
#
# [20 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['eventId', 'teamId', 'homeAway', 'starter', 'athleteDisplayName', 'Pos',
#        'Age', 'Min/Match', 'Save%', 'GA/Match', 'CS%', 'PKsv%', 'Clr/Match',
#        'TklW%', 'Blocks/Match', 'Int/Match', 'Err/Match', 'G+A/Match', 'xAG',
#        'PrgC', 'PrgP', 'KP/Match', 'G+A-PK/Match', 'npxG', 'PrgR', 'SoT%',
#        'Sh/90', 'ATK', 'DEF', 'GK', 'Rating', 'ATK_team_x', 'DEF_team_x',
#        'GK_team_x', 'ATK_team_y', 'DEF_team_y', 'GK_team_y'],
#       dtype='object')
